# %% [markdown]
# ## variable

# %% [markdown]
# ## Bagian1

# %% [markdown]
# varibel dalam python adalah ------ yang terdiri dari beberap value, int, string, dan lainnya

# %%
athooo = 35
anthoo2 = str(athooo)
print(type(athooo))
print(anthoo2)

# %%
umur = 3
nilai = 3.5
nama = "Anthooo"
hadir = True
listt = [1231, "asda", True]
tuplee = ()
kosong = None

# %% [markdown]
# mencetak type dari variable

# %%
print(type(nilai))
# Out:
# <class 'float'>

# %%
nilai2 = str(umur)

# %%
print(nama, nilai)
# Out:
# Anthooo 3.5

# %%
print(type(nilai2))
# Out:
# <class 'bool'>

# %%
nama2 = int(nama)

# %%
print(nama2)

# %% [markdown]
# ## Bagian 2, operasional

# %%
number1 = 17
number2 = 5

# %%
result = number1 * number2
print(result)
# Out:
# 85

# %%
if number1 != number2:    # ==, <=, >=, !=
    print("yayayayay")
else:
    print("nononnonono")
# Out:
# yayayayay

# %%
name = "Python"
iss = " adalah "
snake = "ular"
final = name + iss + snake
nimnama = "12345678 anttho eidio"
print(final)
# Out:
# Python adalah ular

# %%
print(name[5])
# Out:
# n

# %%
print(nimnama[:9])
print(nimnama[9:])
# Out:
# 12345678
# anttho eidio

# %%
umur = 3
nilai = 3.5
nama = "thoooo"
hadir = False
kosong = None

# %%
list1 = [nama, 20, 30, 40, 50]

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
print(list1[0][0:4])
# Out:
# thoo

# %%
nama = "blas "

# %%
print(list1*5)
# Out:
# ['thoooo', 20, 30, 40, 50, 'thoooo', 20, 30, 40, 50, 'thoooo', 20, 30, 40, 50, 'thoooo', 20, 30, 40, 50, 'thoooo', 20, 30, 40, 50]

# %%
print(len(list1))
# Out:
# 5

# %%
list1 = [45, 20, 10, 40, 50, 100]

# %%
list1.append(90)

# %%
print(list1)
# Out:
# [45, 20, 10, 40, 50, 100, 90]

# %%
list1.insert(5, 30)

# %%
print(list1)
# Out:
# [45, 20, 10, 40, 50, 30, 100, 90]

# %%
list1.remove(30)

# %%
print(list1)
# Out:
# [45, 20, 10, 40, 50, 100, 90]

# %%
list1.sort()
print(list1)
# Out:
# [10, 20, 40, 45, 50, 90, 100]

# %%
mean = sum(list1)/len(list1)
print("so, the total mean is =", round(mean, 2), " value")
# Out:
# so, the total mean is = 50.71  value

# %%
print(type(mean))

# %% [markdown]
# # Tugas mandiri

# %%
data_mahasiswa = {
    "Nama": "lala lulu",
    "semester": "3",
    "ipk": 3.2,
    "year": 2024,
    "status": "aktif"
}

# %%
print(data_mahasiswa["ipk"])
# Out:
# 3.2
